# %% [markdown]
# # Machine Learning

# %% [markdown]
# Check Cross Validation Of Merged data of Rent/Income/Trips in Queens
#
# Importing Libraries

# %%
import urllib.request
import tarfile
import os
from pylab import *
# %matplotlib inline
import pandas as pd
import numpy as np

from pandas import DataFrame
from pylab import *
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['linalg', 'draw_if_interactive', 'power', 'fft', 'info', 'random']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# 1) Data Exploration
#
# We are implementing machine learning techniques to perform data analysis and gain knowledge about our data models

# %%
train = pd.read_csv("data/train.csv")
validation = pd.read_csv("data/validation.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-ab7333bbacba> in <module>()
# ----> 1 train = pd.read_csv("data/train.csv")
#       2 validation = pd.read_csv("data/validation.csv")
#
# //anaconda/envs/DataScience-Project/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     560                     skip_blank_lines=skip_blank_lines)
#     561
# --> 562         return _read(filepath_or_buffer, kwds)
#     563
#     564     parser_f.__name__ = name
#
# //anaconda/envs/DataScience-Project/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     313
#     314     # Create the parser.
# --> 315     parser = TextFileReader(filepath_or_buffer, **kwds)
#     316
#     317     if (nrows is not None) and (chunksize is not None):
#
# //anaconda/envs/DataScience-Project/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     643             self.options['has_index_names'] = kwds['has_index_names']
#     644
# --> 645         self._make_engine(self.engine)
#     646
#     647     def close(self):
#
# //anaconda/envs/DataScience-Project/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     797     def _make_engine(self, engine='c'):
#     798         if engine == 'c':
# --> 799             self._engine = CParserWrapper(self.f, **self.options)
#     800         else:
#     801             if engine == 'python':
#
# //anaconda/envs/DataScience-Project/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1211         kwds['allow_leading_cols'] = self.index_col is not False
#    1212
# -> 1213         self._reader = _parser.TextReader(src, **kwds)
#    1214
#    1215         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3427)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6861)()
#
# OSError: File b'data/train.csv' does not exist

# %% [markdown]
# Check what is on train data

# %%
train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-058d1d044437> in <module>()
# ----> 1 train.head()
#
# NameError: name 'train' is not defined

# %% [markdown]
# Check What Is On Validation Data

# %%
validation.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-91ba50e2e0ed> in <module>()
# ----> 1 validation.head()
#
# NameError: name 'validation' is not defined

# %% [markdown]
# Check The Value Count Of The Train Data

# %%
for col in train:
    print(train[col].value_counts())
    print("=========================================\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-7733d991b53b> in <module>()
# ----> 1 for col in train:
#       2     print(train[col].value_counts())
#       3     print("=========================================\n")
#
# NameError: name 'train' is not defined

# %% [markdown]
# Check The Value Count Of The Validation Data

# %%
for col in validation:
    print(validation[col].value_counts())
    print("=========================================\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-836faf5294d4> in <module>()
# ----> 1 for col in validation:
#       2     print(validation[col].value_counts())
#       3     print("=========================================\n")
#
# NameError: name 'validation' is not defined

# %% [markdown]
# Histogram For Train Data

# %%
train.hist(figsize=(16,9))
plt.subplots_adjust(hspace=.5, wspace=.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b708efce16fe> in <module>()
# ----> 1 train.hist(figsize=(16,9))
#       2 plt.subplots_adjust(hspace=.5, wspace=.5)
#       3 plt.show()
#
# NameError: name 'train' is not defined

# %% [markdown]
# Histogram For Validation Data

# %%
validation.hist(figsize=(16,9))
plt.subplots_adjust(hspace=.5, wspace=.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-23dac3d666f9> in <module>()
# ----> 1 validation.hist(figsize=(16,9))
#       2 plt.subplots_adjust(hspace=.5, wspace=.5)
#       3 plt.show()
#
# NameError: name 'validation' is not defined

# %% [markdown]
# Train Trips In Brooklyn

# %%
train["Trips"].hist(bins=250, figsize=(16,9))
plt.xlim(0, 1000)
plt.xticks(range(0,1000, 50))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-fdcdc28909be> in <module>()
# ----> 1 train["Trips"].hist(bins=250, figsize=(16,9))
#       2 plt.xlim(0, 1000)
#       3 plt.xticks(range(0,1000, 50))
#       4 plt.show()
#
# NameError: name 'train' is not defined

# %% [markdown]
# Create a pairwise scatter plot of the columns: year, CountyName,Rent_Mean,StateName,rent0, rent1, rent2, rent3, rent4, state, total, 0, 10, 15, 20, 25, 30, 35, 40, 45.

# %%
pd.scatter_matrix(train[["Trips", "year", "CountyName","Rent_Mean","StateName","rent0", "rent1", "rent2", "rent3", "rent4", "state", "total", "0", "10", "15", "20", "25", "30", "35", "40", "45"]], figsize=(16,9))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b26cab0a56c5> in <module>()
# ----> 1 pd.scatter_matrix(train[["Trips", "pctmale", "age", "pctgt1", "pctgt2", "pctgt5"]], figsize=(16,9))
#       2 plt.show()
#
# NameError: name 'train' is not defined

# %% [markdown]
# 2)Data Prep and Intro to Linear Regression

# %% [markdown]
# Try to eliminate categorical variables, and impute missing values with pandas.
# Return two pandas data frames:
# 1)A data frame with all categorical items and a user-specified response column removed.
# 2)A data frame that contains only the response column.

# %%
def basic_prep(data, col):
    
    trash = ['CountyName','StateName','state']
    not_trash = data.drop(trash, axis=1)
    
    # - impute missing values with the mean of those columns, use pandas ".fillna" function to accomplish this.
    not_trash = not_trash.fillna(not_trash.mean())
    
    return (not_trash.drop([col], axis=1), pd.DataFrame(not_trash[col]))

#This will create two new data frames, one that contains training data - in this case all the numeric columns,
#and one that contains response data - in this case, the "plays" column.
train_basic_features, train_basic_response = basic_prep(train, 'Trips')
validation_basic_features, validation_basic_response = basic_prep(validation, 'Trips')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-07c841e215db> in <module>()
#      11 #This will create two new data frames, one that contains training data - in this case all the numeric columns,
#      12 #and one that contains response data - in this case, the "plays" column.
# ---> 13 train_basic_features, train_basic_response = basic_prep(train, 'Trips')
#      14 validation_basic_features, validation_basic_response = basic_prep(validation, 'Trips')
#
# NameError: name 'train' is not defined

# %%
train_basic_features.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a6a88d32253c> in <module>()
# ----> 1 train_basic_features.head()
#
# NameError: name 'train_basic_features' is not defined

# %% [markdown]
# Fit a LinearRegression model with scikit-learn and return the model score on both the training data and the validation data.

# %%
from sklearn import linear_model

def fit_model(X, y):
    # - Write a function that fits a linear model to a dataset given a column of values to predict.
    return linear_model.LinearRegression().fit(X,y)

def score_model(model, X, y, Xv, yv):
    # - Write a function that returns scores of a model given its training 
    #features and response and validation features and response. 
    #The output should be a tuple of two model scores.
    return (model.score(X,y), model.score(Xv,yv))

def fit_model_and_score(data, response, validation, val_response):
    # - Given a training dataset, a validation dataset, and the name of a column to predict, 
    #Using the model's ".score()" method, return the model score on the training data *and* the validation data
    #as a tuple of two doubles.
    return score_model(fit_model(data, response), data, response, validation, val_response)

print(fit_model_and_score(train_basic_features, train_basic_response, validation_basic_features, validation_basic_response))

model = fit_model(train_basic_features, train_basic_response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c3cb8f612408> in <module>()
#      17     return score_model(fit_model(data, response), data, response, validation, val_response)
#      18
# ---> 19 print(fit_model_and_score(train_basic_features, train_basic_response, validation_basic_features, validation_basic_response))
#      20
#      21 model = fit_model(train_basic_features, train_basic_response)
#
# NameError: name 'train_basic_features' is not defined

# %% [markdown]
#  linear models - Scores should be significantly higher than 0 and less than 1.
#  Residual Function: Calculate the residuals of the model.
#  Plot a histogram.

# %%
def residuals(features, y, model):
    # - Write a function that calculates model residuals given input features, ground truth, and the model.
    return model.predict(features) - y

# - Plot the histogram of the residuals of your current model.
residuals(train_basic_features, train_basic_response, model).hist(bins=250, figsize=(16,9))
plt.xlim(-1000, 150)
plt.xticks(range(-1000, 150, 50))
plt.show()
