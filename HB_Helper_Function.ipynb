# %% [markdown]
# # Machine Learning

# %% [markdown]
# Check Cross Validation Of Merged data of Rent/Income/Trips in brooklyn
#
# Importing Libraries

# %%
import urllib.request
import tarfile
import os
from pylab import *
# %matplotlib inline
import pandas as pd
import numpy as np

from pandas import DataFrame
from pylab import *
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['linalg', 'draw_if_interactive', 'power', 'fft', 'info', 'random']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# 1) Data Exploration
#
# We are implementing machine learning techniques to perform data analysis and gain knowledge about our data models

# %%
train = pd.read_csv("data/train.csv")
validation = pd.read_csv("data/validation.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-ab7333bbacba> in <module>()
# ----> 1 train = pd.read_csv("data/train.csv")
#       2 validation = pd.read_csv("data/validation.csv")
#
# ...

# %% [markdown]
# Check what is on train data

# %%
train.head()

# %% [markdown]
# Check What Is On Validation Data

# %%
validation.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-91ba50e2e0ed> in <module>()
# ----> 1 validation.head()
#
# NameError: name 'validation' is not defined

# %% [markdown]
# Check The Value Count Of The Train Data

# %%
for col in train:
    print(train[col].value_counts())
    print("=========================================\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7733d991b53b> in <module>()
# ----> 1 for col in train:
#       2     print(train[col].value_counts())
#       3     print("=========================================\n")
#
# NameError: name 'train' is not defined

# %% [markdown]
# Check The Value Count Of The Validation Data

# %%
for col in validation:
    print(validation[col].value_counts())
    print("=========================================\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-836faf5294d4> in <module>()
# ----> 1 for col in validation:
#       2     print(validation[col].value_counts())
#       3     print("=========================================\n")
#
# NameError: name 'validation' is not defined

# %% [markdown]
# Histogram For Train Data

# %%
train.hist(figsize=(16,9))
plt.subplots_adjust(hspace=.5, wspace=.5)
plt.show()

# %% [markdown]
# Histogram For Validation Data

# %%
validation.hist(figsize=(16,9))
plt.subplots_adjust(hspace=.5, wspace=.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-23dac3d666f9> in <module>()
# ----> 1 validation.hist(figsize=(16,9))
#       2 plt.subplots_adjust(hspace=.5, wspace=.5)
#       3 plt.show()
#
# NameError: name 'validation' is not defined

# %% [markdown]
# Train Trips In Brooklyn

# %%
train["Trips"].hist(bins=250, figsize=(16,9))
plt.xlim(0, 1000)
plt.xticks(range(0,1000, 50))
plt.show()

# %% [markdown]
# Create a pairwise scatter plot of the columns: plays, pctmale, age, pctgt1, pctgt2, pctgt5.
