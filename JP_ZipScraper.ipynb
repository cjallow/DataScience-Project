# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#added this because it's indicated as useful but not imported
import urllib
from zipfile import ZipFile
from io import BytesIO
import os
import json
from bs4 import BeautifulSoup as bs
import re

from matplotlib import animation, rc
from IPython.display import display, HTML

# %%
bkzips = "http://www.brooklyn.com/zipcodes.php"

# %%
ziphtml = urllib.request.urlopen(bkzips).read().decode('utf-8')
soup = bs(ziphtml, 'html.parser')
borough = ""
zipcodes = []
for row in soup.find_all('tr'):
    cols = row.find_all('td')
    if len(cols) >= 2:
        neighborhood = cols[0].text.replace("\n", "")
        for zipcode in re.compile("\s*,\s*").split(cols[1].text):
            zipcodes.append({"neighborhood": neighborhood, "zipcode": zipcode})
    else:
        print(cols)
zipDF = pd.DataFrame(zipcodes)
zipDF.head()
# Out:
# []
#                 neighborhood zipcode
# 0  Albemarle-Kenmore Terrace   11226
# 1                 Bath Beach   11214
# 2                  Bay Ridge   11209
# 3         Bedford Stuyvesant   11216
# 4                Bensonhurst   11214

# %%
zipDF
# Out:
#                  neighborhood zipcode
# 0   Albemarle-Kenmore Terrace   11226
# 1                  Bath Beach   11214
# 2                   Bay Ridge   11209
# 3          Bedford Stuyvesant   11216
# 4                 Bensonhurst   11214
# 5                Bergen Beach   11234
# 6        Beverley Square East   11226
# 7        Beverley Square West   11226
# 8                 Boerum Hill   11201
# 9                 Boerum Hill   11217
# 10               Borough Park   11219
# 11               Borough Park   11204
# 12             Brighton Beach   11235
# 13          Broadway Junction   11233
# 14           Brooklyn Heights   11201
# 15                Brownsville   11212
# 16                   Bushwick   11221
# 17                   Canarsie   11236
# 18            Carroll Gardens   11231
# 19                 Caton Park   11218
# 20                  City Line   11207
# 21               Clinton Hill   11205
# 22                Cobble Hill   11201
# 23               Coney Island   11224
# 24              Crown Heights   11225
# 25              Crown Heights   11213
# 26        Crown Heights North   11213
# 27              Cypress Hills   11208
# 28                Ditmas Park   11226
# 29           Ditmas Park West   11226
# ..                        ...     ...
# 67              Ocean Parkway   11230
# 68            Paerdegat Basin   11236
# 69                 Park Slope   11215
# 70                 Park Slope   11217
# 71                 Plum Beach   11235
# 72  Prospect Lefferts Gardens   11225
# 73           Prospect Heights   11217
# 74           Prospect Heights   11238
# 75        Prospect Park South   11217
# 76                   Red Hook   11231
# 77             Remsen Village   11236
# 78                      Rugby   11203
# 79                   Sea Gate   11224
# 80             Sheepshead Bay   11235
# 81              South Midwood   11210
# 82                 South Side   11210
# 83           South Park Slope   11215
# 84               Spring Creek   11239
# 85            Stable Brooklyn   11218
# 86              Starrett City   11239
# 87         Stuyvesant Heights   11216
# 88                Sunset Park   11220
# 89               Vinegar Hill   11201
# 90                 Weeksville   11233
# 91               West Midwood   11230
# 92               Williamsburg   11206
# 93               Williamsburg   11211
# 94               Williamsburg   11249
# 95            Windsor Terrace   11218
# 96                    Wingate   11203
#
# [97 rows x 2 columns]

# %%
len(zipDF["zipcode"].values)
# Out:
# 97

# %%
len(set(zipDF["zipcode"].values))
# Out:
# 37

# %%
zipDF.sort("zipcode")
# Out:
# /home/stuff/anaconda3/envs/DataScience-Project/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#          neighborhood zipcode
# 8         Boerum Hill   11201
# 14   Brooklyn Heights   11201
# 30           Downtown   11201
# 31              DUMBO   11201
# 89       Vinegar Hill   11201
# 22        Cobble Hill   11201
# 43       Fulton Ferry   11201
# 78              Rugby   11203
# 33      East Flatbush   11203
# 96            Wingate   11203
# 11       Borough Park   11204
# 53           Mapleton   11204
# 41        Fort Greene   11205
# 21       Clinton Hill   11205
# 62          Navy Yard   11205
# 92       Williamsburg   11206
# 36  East Williamsburg   11206
# 34      East New York   11207
# 20          City Line   11207
# 50      Highland Park   11207
# 35      East New York   11208
# 27      Cypress Hills   11208
# 2           Bay Ridge   11209
# 42      Fort Hamilton   11209
# 59       Midwood Park   11210
# 82         South Side   11210
# 81      South Midwood   11210
# 37           Farragut   11210
# 64         North Side   11211
# 93       Williamsburg   11211
# ..                ...     ...
# 58            Midwood   11230
# 91       West Midwood   11230
# 67      Ocean Parkway   11230
# 56  Manhattan Terrace   11230
# 38      Fiske Terrace   11230
# 18    Carroll Gardens   11231
# 76           Red Hook   11231
# 46            Gowanus   11231
# 49  Greenwood Heights   11232
# 66         Ocean Hill   11233
# 13  Broadway Junction   11233
# 90         Weeksville   11233
# 61        Mill Island   11234
# 5        Bergen Beach   11234
# 55    Manhattan Beach   11234
# 60         Mill Basin   11234
# 57        Marine Park   11234
# 71         Plum Beach   11235
# 80     Sheepshead Bay   11235
# 12     Brighton Beach   11235
# 77     Remsen Village   11236
# 68    Paerdegat Basin   11236
# 40          Flatlands   11236
# 63           New Lots   11236
# 17           Canarsie   11236
# 74   Prospect Heights   11238
# 84       Spring Creek   11239
# 51          Homecrest   11239
# 86      Starrett City   11239
# 94       Williamsburg   11249
#
# [97 rows x 2 columns]

# %%
set(zipDF["neighborhood"].values)
# Out:
# {'Albemarle-Kenmore Terrace',
#  'Bath Beach',
#  'Bay Ridge',
#  'Bedford Stuyvesant',
#  'Bensonhurst',
#  'Bergen Beach',
#  'Beverley Square East',
#  'Beverley Square West',
#  'Boerum Hill',
#  'Borough Park',
#  'Brighton Beach',
#  'Broadway Junction',
#  'Brooklyn Heights',
#  'Brownsville',
#  'Bushwick',
#  'Canarsie',
#  'Carroll Gardens',
#  'Caton Park',
#  'City Line',
#  'Clinton Hill',
#  'Cobble Hill',
#  'Coney Island',
#  'Crown Heights',
#  'Crown Heights North',
#  'Cypress Hills',
#  'DUMBO',
#  'Ditmas Park',
#  'Ditmas Park West',
#  'Downtown',
#  'Dyker Heights',
#  'East Flatbush',
#  'East New York',
#  'East Williamsburg',
#  'Farragut',
#  'Fiske Terrace',
#  'Flatbush',
#  'Flatlands',
#  'Fort Greene',
#  'Fort Hamilton',
#  'Fulton Ferry',
#  'Georgetown',
#  'Gerritsen Beach',
#  'Gowanus',
#  'Gravesend',
#  'Greenpoint',
#  'Greenwood Heights',
#  'Highland Park',
#  'Homecrest',
#  'Kensington',
#  'Madison',
#  'Manhattan Beach',
#  'Manhattan Terrace',
#  'Mapleton',
#  'Marine Park',
#  'Midwood',
#  'Midwood Park',
#  'Mill Basin',
#  'Mill Island',
#  'Navy Yard',
#  'New Lots',
#  'North Side',
#  'Northeast Flatbush',
#  'Ocean Hill',
#  'Ocean Parkway',
#  'Paerdegat Basin',
#  'Park Slope',
#  'Plum Beach',
#  'Prospect Heights',
#  'Prospect Lefferts Gardens',
#  'Prospect Park South',
#  'Red Hook',
#  'Remsen Village',
#  'Rugby',
#  'Sea Gate',
#  'Sheepshead Bay',
#  'South Midwood',
#  'South Park Slope',
#  'South Side',
#  'Spring Creek',
#  'Stable Brooklyn',
#  'Starrett City',
#  'Stuyvesant Heights',
#  'Sunset Park',
#  'Vinegar Hill',
#  'Weeksville',
#  'West Midwood',
#  'Williamsburg',
#  'Windsor Terrace',
#  'Wingate'}
